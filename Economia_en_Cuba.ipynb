# %% [markdown]
# # Proyecto Final de Introducción a la Ciencia de Datos
#
#  ## Tema: Análisis de la Economía Cubana
#
# #### Subtema: La vida de un graduado
#
# #### Autora: Laura Margarita Aguilar Diaz

# %% [markdown]
# ### Introducción:

# %% [markdown]
# ##### Durante este proyecto de Introducción a la Ciencia de Datos, se explora la económica de los recién graduados universitarios en el contexto actual de La Habana. A través de la recopilación de datos de Mipymes. El objetivo final es determinar la realidad económica que enfrenta un egresado y los recursos con los que cuenta para afrontarla.

# %% [markdown]
# ### Biblioteca utilizada:

# %%
from WeLoveYudivian import *

# %% [markdown]
# ##### Incluso antes de obtener su título, los estudiantes ya gestionan pequeños ingresos mensuales , lo que les da una primera experiencia en el manejo de sus propias finanzas y gastos.

# %%
estipendio_estudiantil()

# %% [markdown]
# ##### Los salarios se fijan según parámetros específicos de cada profesión, por lo que su promedio varía entre distintas ocupaciones.

# %%
graf_sector_salary()

# %% [markdown]
# ##### Mujeres y hombres tienen derecho al trabajo; sin embargo, la decisión de muchos jóvenes de emigrar provoca un descenso progresivo de la fuerza laboral

# %%
graf_distribucion_trabajo()

# %% [markdown]
# ##### El análisis de los datos confirma que los trabajadores mayoritarios son hombres.

# %% [markdown]
# ##### A lo largo de los años, diversos fenómenos han impactado la economía nacional, provocando un aumento sustancial de la inflación y, en consecuencia, del presupuesto estatal destinado a los salarios.

# %%
graf_salario()

# %% [markdown]
# ##### El salario ha aumentado, pero el precio de los productos también. Por lo tanto, el incremento real no se percibe.

# %% [markdown]
# ##### Las MIPYMES (Micro, Pequeñas y Medianas Empresas) son entidades independientes que predominan en el sector comercial y, en menor medida, en el productivo. A continuación se detallan los nombres y direcciones de aquellas de las que se extrajo la información para el análisis de datos.

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# ##### Resulta más fácil visualizar la cantidad de pequeños emprendimientos analizados por municipio

# %%
graf_cant_muni()

# %% [markdown]
# ##### Sobresale una clara paradoja: los productos considerados esenciales para la supervivencia humana no son, en este caso, los más ofertados.

# %%
graf_distri_product()

# %% [markdown]
# ##### Considerando el salario promedio mensual del país, ¿es posible adquirir, de manera individual, los productos básicos necesarios?

# %%
graf_salario_prod()

# %% [markdown]
# ##### ¿Cuántos días se debe trabajar para comprar ciertos productos?

# %%
graf_count_prod()

# %% [markdown]
# ##### Durante 30 días consecutivos, la tasa de cambio del mercado informal (según ElToque) mostró una constante fluctuación. El algoritmo evolucionó en respuesta a eventos en tiempo real.

# %%
tasa_cambio()

# %% [markdown]
# ##### Dos tasas de cambio rigen la economía: la formal e informal. Ambas definen el precio y la oferta de los productos.

# %%
graf_tasa_product()

# %% [markdown]
# ##### Existen dos alternativas frecuentes al adquirir productos: comprar en mipymes (con precios en moneda nacional) o en tiendas que cotizan en dólares. Desde el punto de vista económico, ¿qué resulta más ventajoso: pagar en la moneda local o directamente en dólares?

# %%
graf_comp_usd_cup()

# %% [markdown]
# ##### Tras evaluar las dos opciones de compra, se concluyó que el único producto con un precio accesible cuando se paga en divisa es la leche en polvo.

# %% [markdown]
# ### Conclusión:

# %% [markdown]
# ##### El salario inicial de un egresado universitario frecuentemente resulta insuficiente para cubrir el costo completo de los alimentos básicos del hogar. Esta brecha se complica aún más en entornos donde conviven precios en moneda local y en dólares, ya que la persona debe realizar cálculos constantes de tipo de cambio y priorización para decidir dónde, cuánto y cómo realizar sus compras, lo que limita significativamente su capacidad de planificación y autonomía financiera.
