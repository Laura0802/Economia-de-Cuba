# %% [markdown]
# # Proyecto Final de Introducción a la Ciencia de Datos
#
#  ## Tema: Análisis de la Economía Cubana
#
# #### Subtema: La Vida de un Egresado
#
# #### Autora: Laura Margarita Aguilar Diaz

# %% [markdown]
# ---

# %% [markdown]
# ### Introducción:

# %% [markdown]
# ##### Durante este proyecto de Introducción a la Ciencia de Datos, se analiza la situación económica de los recién graduados universitarios en el contexto de los años 2020 hasta el 2025 en la ciudad de La Habana. El estudio se basa en fundamentar el costo de productos de primera necesidad, tanto de alimentos como aseo, en las mipymes. El objetivo es demostrar cómo impactan los precios de los productos en la vida de un egresado y crear una guía que sirva como referencia para visualizar lo que se podría obtener al alcanzar una mayor libertad financiera.

# %% [markdown]
# ---

# %% [markdown]
# ### Biblioteca utilizada:

# %%
from WeLoveYudivian import *

# %% [markdown]
# ---

# %% [markdown]
# ##### Durante la universidad, el estipendio estudiantil funciona como un presupuesto de entrenamiento en un entorno académico protegido. Al graduarse, el primer salario profesional —aunque numéricamente mayor— enfrenta al egresado a la realidad del mercado: los precios de los productos esenciales siguen una lógica que reduce drásticamente su poder adquisitivo real. Este "shock del egreso" revela que la brecha crítica no está entre el estipendio y el salario, sino entre el monto que recibe y lo que realmente puede adquirir con él para cubrir sus necesidades básicas.

# %%
estipendio_estudiantil()

# %% [markdown]
# ##### Para cubrir las necesidades básicas, un recién graduado encontraría mayor viabilidad económica en sectores que operan con dinámicas de mercado y conexión internacional, como el turismo, la tecnología, o empresas con capital extranjero, donde los ingresos tienen una relación más realista con el costo de la vida. En contraste, las profesiones dentro del sector estatal tradicional, aunque socialmente valiosas, ofrecen salarios que rara vez alcanzan para cubrir una canasta completa de productos esenciales, lo que obliga a buscar ingresos complementarios o a depender de apoyo familiar. La elección de carrera, por tanto, impacta directamente en la capacidad de lograr independencia financiera tras la graduación.

# %%
graf_sector_salary()

# %% [markdown]
# ##### A pesar de que el presupuesto ha destinado mayor cantidad de fondos al incremento salarial, debido a la inflación, el acceso se ha comportado de la siguiente manera:

# %%
graf_salario()

# %% [markdown]
# ##### Las MIPYMES (Micro, Pequeñas y Medianas Empresas) son entidades independientes que predominan en el sector comercial y, en menor medida, en el productivo. A continuación se detallan los nombres y direcciones de aquellas de las que se extrajo la información para el análisis de datos.

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# ##### La distribución de los emprendimientos analizados en la muestra, organizada por municipios, permite visualizar de manera inmediata la cobertura geográfica y la diversidad de establecimientos incluidos en el estudio.

# %%
graf_cant_muni()

# %% [markdown]
# ##### Considerando el salario promedio mensual en el país, adquirir de manera individual los productos básicos necesarios resulta inviable, ya que el costo total de una canasta mínima de productos esenciales supera considerablemente el monto de dicho ingreso. Esta brecha obliga a estrategias como el compartir gastos en un hogar, depender de ingresos complementarios o priorizar solo algunos productos, renunciando a otros igualmente necesarios para el bienestar básico.

# %%
graf_salario_prod()

# %% [markdown]
# ##### Para adquirir productos básicos como alimentos o artículos de higiene, una persona con salario promedio debe destinar uno o varios días completos de su sueldo por cada artículo. Esto significa que cada compra esencial representa una parte importante del esfuerzo laboral del mes, limitando la posibilidad de adquirir todos los productos necesarios en un solo ciclo de pago.

# %%
graf_count_prod()

# %% [markdown]
# ##### La tasa de cambio oficial, publicada por el Banco Central, difiere significativamente de la tasa informal seguida en plataformas como ElToque. Mientras la primera es el referente formal, la segunda es la que realmente influye en los precios de los productos básicos que la población adquiere día a día, reduciendo el poder adquisitivo real de los salarios.

# %%
tasa_cambio()

# %% [markdown]
# ##### En Cuba, la tasa de cambio oficial y la informal definen precios distintos para los mismos productos. Mientras el salario se calcula con la primera, la mayoría de los bienes se comercian según la segunda, lo que reduce drásticamente lo que las personas pueden comprar realmente.

# %%
graf_tasa_product()

# %% [markdown]
# ##### Existen dos alternativas frecuentes al adquirir productos: comprar en mipymes (con precios en moneda nacional) o en tiendas que cotizan en dólares. Desde el punto de vista económico, ¿qué resulta más ventajoso: pagar en la moneda local o directamente en dólares?

# %%
graf_comp_usd_cup()

# %% [markdown]
# ##### Tras comparar los precios en ambas opciones de compra, se observa que la leche en polvo es el único producto básico cuyo costo resulta significativamente más accesible cuando se adquiere en tiendas que venden en dólares, en comparación con su precio convertido a la tasa informal en establecimientos que comercian en pesos cubanos. Este caso específico representa una excepción notable dentro de una tendencia general donde los precios en ambas monedas suelen equivalerse.

# %% [markdown]
# ---

# %% [markdown]
# ### Conclusión:

# %% [markdown]
# ##### El salario con el que comienza un recién graduado rara vez es suficiente para cubrir la compra completa de los alimentos básicos que necesita un hogar, creando una brecha financiera desde el primer momento de su carrera. Esta situación se hace más compleja al tener que comprar en un mercado donde unos productos se venden en pesos cubanos y otros en dólares. La persona debe estar constantemente calculando equivalencias, comparando en qué moneda le resulta menos costoso cada artículo, y decidiendo qué es prioritario comprar dentro de su presupuesto limitado.
#
# ##### Esta necesidad de tomar decisiones financieras minuciosas a diario, sumada a la fluctuación de los precios y del tipo de cambio informal, hace muy difícil planificar con tranquilidad los gastos del mes. En lugar de poder organizar sus finanzas con anticipación, el egresado se ve inmerso en una gestión reactiva de su dinero, donde la incertidumbre sobre el costo de la vida limita significativamente su independencia y su capacidad para construir una estabilidad económica personal.
